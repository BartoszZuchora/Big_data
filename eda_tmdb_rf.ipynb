# %% [markdown]
# # TMDB 10000 Movies (2022) — EDA + RandomForest (sanity-check)
#
# **Uwaga dot. wymagań projektu:**
# - Ten notebook jest **pomocniczy** (EDA + wizualizacja + model sanity-check w scikit-learn).
# - Wymagane modele i tuning realizowane są w **Apache Spark / Spark MLlib** (`tmdb_spark_ml.py`).
# - Wymagany streaming (Kafka + Spark Structured Streaming) realizują `front_app.py` + `stream_predict.py`.
#
# ## Definicja sukcesu (spójna z projektem Spark)
# - **SUKCES / hit**: `vote_average >= 7.0`
# - **NIE-SUKCES**: `vote_average < 7.0`

# %%
# !pip -q install pandas numpy matplotlib seaborn scikit-learn

import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    ConfusionMatrixDisplay,
    roc_auc_score,
)
from sklearn.ensemble import RandomForestClassifier

pd.set_option("display.max_columns", 200)
pd.set_option("display.width", 140)
sns.set_theme(style="whitegrid")

RANDOM_STATE = 42
LABEL_THRESHOLD = 7.0
# Out:
# [notice] A new release of pip is available: 24.3.1 -> 26.0
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ## 1) Wczytanie danych

# %%
DATA_PATH = "./data/tmdb_10000_movies.csv"  # <- ustaw prawidłową ścieżkę
assert os.path.exists(DATA_PATH), f"Nie znaleziono pliku: {DATA_PATH}"

df = pd.read_csv(DATA_PATH)
print("Shape:", df.shape)
df.head()
# Out:
# Shape: (10000, 14)
#        adult                     backdrop_path                genre_ids      id original_language                  original_title  \
# 0      False  /xDMIl84Qo5Tsu62c9DGWhmPI67A.jpg            [28, 12, 878]  505642                en  Black Panther: Wakanda Forever
# 1      False  /faXT8V80JRhnArTAeYXz0Eutpv9.jpg  [16, 12, 35, 10751, 14]  315162                en    Puss in Boots: The Last Wish
# 2      False  /q2fY4kMXKoGv4CQf310MCxpXlRI.jpg            [878, 27, 35]  536554                en                           M3GAN
# 3      False  /s16H6tpK2utvwDtzZ8Qy4qm5Emw.jpg            [878, 12, 28]   76600                en        Avatar: The Way of Water
# 4      False  /Aqldsq65Nj1KAkQD2MzkZsAk5N5.jpg             [28, 53, 18]  846433                es                    The Enforcer
#
#                                             overview  popularity                       poster_path release_date  \
# ...

# %% [markdown]
# ## 2) Szybka kontrola jakości (braki, duplikaty)

# %%
n_duplicates = df.duplicated().sum()
print("Duplikaty wierszy:", n_duplicates)

missing = df.isna().mean().sort_values(ascending=False)
display(missing.head(20).to_frame("missing_rate"))
# Out:
# Duplikaty wierszy: 0
#                    missing_rate
# backdrop_path            0.3314
# overview                 0.0943
# poster_path              0.0408
#     adult                0.0000
# genre_ids                0.0000
# id                       0.0000
# original_language        0.0000
# original_title           0.0000
# popularity               0.0000
# release_date             0.0000
# title                    0.0000
# video                    0.0000
# vote_average             0.0000
# vote_count               0.0000

# %% [markdown]
# ## 3) Target (etykieta) — spójny z projektem Spark
#
# `target_hit = 1` jeśli `vote_average >= 7.0`

# %%
assert "vote_average" in df.columns, "Brak kolumny vote_average"

df["vote_average"] = pd.to_numeric(df["vote_average"], errors="coerce")
df = df[df["vote_average"].notna()].copy()

df["target_hit"] = (df["vote_average"] >= LABEL_THRESHOLD).astype(int)
print("Próg vote_average:", LABEL_THRESHOLD)
df["target_hit"].value_counts(normalize=True).rename("share")
# Out:
# Próg vote_average: 7.0
# target_hit
# 0    0.7838
# 1    0.2162
# Name: share, dtype: float64

# %% [markdown]
# ## 4) Wybór cech (baseline, bez leakage)
#
# Usuwamy `vote_average` (bo tworzy label) oraz typowe identyfikatory/teksty w baseline.

# %%
target_col = "target_hit"

drop_cols = {target_col, "vote_average"}  # leakage

for c in ["id", "imdb_id", "tmdb_id", "title", "original_title", "poster_path", "backdrop_path", "overview"]:
    if c in df.columns:
        drop_cols.add(c)

# Usuń też bardzo długie teksty
for c in df.columns:
    if df[c].dtype == "object":
        avg_len = df[c].dropna().astype(str).str.len().mean() if df[c].notna().any() else 0
        if avg_len and avg_len > 80:
            drop_cols.add(c)

X = df.drop(columns=[c for c in drop_cols if c in df.columns])
y = df[target_col].astype(int)

print("X shape:", X.shape)
display(y.value_counts().to_frame("count"))

num_features = [c for c in X.columns if pd.api.types.is_numeric_dtype(X[c])]
cat_features = [c for c in X.columns if X[c].dtype == "object"]

print("Num features:", len(num_features))
print("Cat features:", len(cat_features))
display(pd.DataFrame({"num": num_features}).head(30))
display(pd.DataFrame({"cat": cat_features}).head(30))
# Out:
# X shape: (10000, 7)
#             count
# target_hit
# 0            7838
# 1            2162
# Num features: 4
# Cat features: 0
#           num
# 0       adult
# 1  popularity
# 2       video
# 3  vote_count
# Empty DataFrame
# Columns: [cat]
# Index: []

# %% [markdown]
# ## 5) Model: RandomForestClassifier + metryki + macierz pomyłek
#
# Pipeline:
# - num: imputacja medianą
# - cat: imputacja + OneHotEncoder
# - model: RandomForest

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.2,
    random_state=RANDOM_STATE,
    stratify=y,
)

numeric_transformer = Pipeline(
    steps=[
        ("imputer", SimpleImputer(strategy="median")),
    ]
)

categorical_transformer = Pipeline(
    steps=[
        ("imputer", SimpleImputer(strategy="most_frequent")),
        ("onehot", OneHotEncoder(handle_unknown="ignore", min_frequency=10)),
    ]
)

preprocess = ColumnTransformer(
    transformers=[
        ("num", numeric_transformer, num_features),
        ("cat", categorical_transformer, cat_features),
    ],
    remainder="drop",
)

# RandomForest — parametry bezpieczne na laptopie
rf = RandomForestClassifier(
    n_estimators=300,
    max_depth=12,
    min_samples_leaf=2,
    random_state=RANDOM_STATE,
    n_jobs=-1,
)

model = Pipeline(steps=[("preprocess", preprocess), ("rf", rf)])

model.fit(X_train, y_train)
y_pred = model.predict(X_test)

print(classification_report(y_test, y_pred, digits=4))

# Confusion matrix
cm = confusion_matrix(y_test, y_pred, labels=[0, 1])

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=[0, 1])
disp.plot(values_format="d", cmap="Blues", colorbar=False)

# Nakładamy etykiety TN/FP/FN/TP + wartość
labels = [["TN", "FP"],
          ["FN", "TP"]]

for i in range(2):
    for j in range(2):
        disp.text_[i, j].set_text(f"{labels[i][j]}\n{cm[i, j]}")
        disp.text_[i, j].set_color("black")
        disp.text_[i, j].set_fontsize(12)

plt.title("Macierz pomyłek - RandomForest (sanity-check)", color="black")
plt.tight_layout()
plt.show()

# ROC-AUC
if hasattr(model.named_steps["rf"], "predict_proba"):
    y_proba = model.predict_proba(X_test)[:, 1]
    auc = roc_auc_score(y_test, y_proba)
    print("ROC-AUC:", round(auc, 4))
# Out:
#               precision    recall  f1-score   support
#
#            0     0.8206    0.9216    0.8681      1568
#            1     0.4854    0.2685    0.3458       432
#
#     accuracy                         0.7805      2000
#    macro avg     0.6530    0.5950    0.6069      2000
# weighted avg     0.7482    0.7805    0.7553      2000
# ROC-AUC: 0.8154

# %%
# === Feature importance tylko dla: popularity, vote_count (RandomForest pipeline) ===
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.inspection import permutation_importance

keep = ["popularity", "vote_count"]

# 1) Sprawdź, że te kolumny są w X (tym już po drop_cols)
missing_keep = [c for c in keep if c not in X.columns]
assert not missing_keep, f"Brakuje kolumn: {missing_keep}"

# 2) Mini-dataset tylko z 2 cech
X2 = X[keep].copy()
y2 = y.copy()

# 3) Split jak wcześniej
X2_train, X2_test, y2_train, y2_test = train_test_split(
    X2, y2,
    test_size=0.2,
    random_state=RANDOM_STATE,
    stratify=y2
)

# 4) Preprocess: tylko num (imputer)
numeric_transformer_2 = Pipeline(steps=[
    ("imputer", SimpleImputer(strategy="median")),
])

preprocess_2 = ColumnTransformer(
    transformers=[
        ("num", numeric_transformer_2, keep),
    ],
    remainder="drop",
)

# 5) Ten sam RandomForest (jak u Ciebie)
rf_2 = RandomForestClassifier(
    n_estimators=300,
    max_depth=12,
    min_samples_leaf=2,
    random_state=RANDOM_STATE,
    n_jobs=-1,
)

model_2 = Pipeline(steps=[
    ("preprocess", preprocess_2),
    ("rf", rf_2),
])

model_2.fit(X2_train, y2_train)

# === (A) Wbudowane RF feature_importances_ (MDI) ===
raw_imp = model_2.named_steps["rf"].feature_importances_  # długość 2

imp_pct = 100 * raw_imp / raw_imp.sum() if raw_imp.sum() > 0 else np.zeros_like(raw_imp)

imp_df = pd.DataFrame({
    "feature": keep,
    "importance_raw": raw_imp,
    "importance_%": imp_pct
}).sort_values("importance_%", ascending=False)

print("\n=== RandomForest feature_importances_ (normalized to 100%) ===")
display(imp_df)

plt.figure(figsize=(6, 3))
plt.barh(imp_df["feature"], imp_df["importance_%"])
plt.xlabel("Importance (%) — normalized (RF feature_importances_)")
plt.title("Feature importance: RandomForest (popularity vs vote_count)")
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()

# === (B) Permutation importance (ROC-AUC drop) ===
perm = permutation_importance(
    model_2,
    X2_test,
    y2_test,
    n_repeats=20,
    random_state=RANDOM_STATE,
    scoring="roc_auc"
)

perm_imp = perm.importances_mean

# może być lekko ujemne -> do % ucinamy do 0
perm_clip = np.clip(perm_imp, 0, None)
perm_pct = 100 * perm_clip / perm_clip.sum() if perm_clip.sum() > 0 else np.zeros_like(perm_clip)

perm_df = pd.DataFrame({
    "feature": keep,
    "importance_raw": perm_imp,   # surowy drop AUC (może minimalnie <0)
    "importance_%": perm_pct
}).sort_values("importance_%", ascending=False)

print("\n=== Permutation importance (ROC-AUC drop) (normalized to 100%) ===")
display(perm_df)

plt.figure(figsize=(6, 3))
plt.barh(perm_df["feature"], perm_df["importance_%"])
plt.xlabel("Importance (%) — normalized permutation (roc_auc drop)")
plt.title("Feature importance: Permutation (RF, 2 cechy)")
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()
# Out:
# === RandomForest feature_importances_ (normalized to 100%) ===
#       feature  importance_raw  importance_%
# 1  vote_count        0.601576     60.157626
# 0  popularity        0.398424     39.842374
# === Permutation importance (ROC-AUC drop) (normalized to 100%) ===
#       feature  importance_raw  importance_%
# 1  vote_count        0.322322     90.657063
# 0  popularity        0.033218      9.342937
